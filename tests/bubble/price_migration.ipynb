# %%
from app.services.external_api.bubble_api import BubbleApi
api = BubbleApi("https://app.thebunkering.com/api/1.1/obj", "2b923c424138e7f677205466e0ee87ea")

# %%
prices, err = api.get_all_prices()
# Out:
# Fetching ports from cursor: 0
# Fetched 100 ports. Total so far: 100. Remaining: 300354
# Fetching ports from cursor: 100
# Fetched 100 ports. Total so far: 200. Remaining: 300254
# Fetching ports from cursor: 200
# Fetched 100 ports. Total so far: 300. Remaining: 300154
# Fetching ports from cursor: 300
# Fetched 100 ports. Total so far: 400. Remaining: 300054
# Fetching ports from cursor: 400
# Fetched 100 ports. Total so far: 500. Remaining: 299954
# Fetching ports from cursor: 500
# Fetched 100 ports. Total so far: 600. Remaining: 299854
# Fetching ports from cursor: 600
# Fetched 100 ports. Total so far: 700. Remaining: 299754
# Fetching ports from cursor: 700
# Fetched 100 ports. Total so far: 800. Remaining: 299654
# Fetching ports from cursor: 800
# Fetched 100 ports. Total so far: 900. Remaining: 299554
# Fetching ports from cursor: 900
# Fetched 100 ports. Total so far: 1000. Remaining: 299454
# Fetching ports from cursor: 1000
# ...
